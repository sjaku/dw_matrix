# %%
#!pip install datadotworld
#!pip install datadotworld[pandas]

# %%
#!dw configure

# %%
from google.colab import drive
import pandas as pd
import numpy as np

import datadotworld as dw

# %%
#drive.mount("/content/drive")

# %%
cd "drive/My Drive/Colab Notebooks/dw_matrix"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
ls matrix_one/
# Out:
# day3.ipynb

# %%
# !mkdir data

# %%
ls
# Out:
# data/  HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !echo 'data' > .gitignore

# %%
# !git add .gitignore

# %%
data = dw.load_dataset('datafiniti/mens-shoe-prices')

# %%
df = data.dataframes['7004_1']
df.shape
# Out:
# (19387, 48)

# %%
df.prices_currency.unique
# Out:
# <bound method Series.unique of 0        USD
# 1        USD
# 2        USD
# 3        USD
# 4        USD
# 5        USD
# 6        USD
# 7        USD
# 8        USD
# 9        USD
# 10       USD
# 11       USD
# 12       USD
# 13       USD
# 14       USD
# 15       USD
# 16       USD
# 17       USD
# 18       AUD
# 19       USD
# 20       USD
# 21       USD
# 22       USD
# 23       USD
# 24       USD
# 25       USD
# 26       USD
# 27       USD
# 28       USD
# 29       USD
#         ...
# 19357    USD
# 19358    USD
# 19359    USD
# 19360    USD
# 19361    USD
# 19362    USD
# 19363    USD
# 19364    CAD
# 19365    USD
# 19366    CAD
# 19367    USD
# 19368    USD
# 19369    USD
# 19370    USD
# 19371    USD
# 19372    USD
# 19373    USD
# 19374    USD
# 19375    USD
# 19376    USD
# 19377    USD
# 19378    USD
# 19379    USD
# 19380    USD
# 19381    USD
# 19382    USD
# 19383    USD
# 19384    USD
# 19385    USD
# 19386    USD
# Name: prices_currency, Length: 19387, dtype: object>

# %%
df.prices_currency.unique()
# Out:
# array(['USD', 'AUD', 'CAD', 'EUR', nan, 'GBP', 'New with box',
#        'UnbeatableSale.com, Inc. - Walmart.com',
#        'PalmBeach Jewelry - Walmart.com', 'new', 'New without tags',
#        'SHOEBACCA LTD. - Walmart.com', 'Shoes.com',
#        'Wholesale Costume and Party Supplies - Walmart.com'], dtype=object)

# %%
df.prices_currency.value_counts(normalize=True)
# Out:
# USD                                                   0.959246
# AUD                                                   0.017503
# CAD                                                   0.015691
# EUR                                                   0.005541
# GBP                                                   0.001139
# PalmBeach Jewelry - Walmart.com                       0.000155
# new                                                   0.000155
# New with box                                          0.000155
# UnbeatableSale.com, Inc. - Walmart.com                0.000155
# Wholesale Costume and Party Supplies - Walmart.com    0.000104
# Shoes.com                                             0.000052
# New without tags                                      0.000052
# SHOEBACCA LTD. - Walmart.com                          0.000052
# Name: prices_currency, dtype: float64

# %%
df_usd = df[ df.prices_currency == 'USD'].copy()

# %%
df_usd.shape
# Out:
# (18524, 48)

# %%
#df_usd['prices_amountmin'] = df_usd.prices_amountmin.astype(np.float)
#df_usd['prices_amountmin'].hist()
filter_max = np.percentile( df_usd['prices_amountmin'], 99)
filter_max
# Out:
# 895.0

# %%
df_usd_filter = df_usd[ df_usd['prices_amountmin'] < filter_max]

# %%
df_usd_filter.prices_amountmin.hist(bins=100)

# %%
ls
# Out:
# data/  HelloGitHub.ipynb  LICENSE  matrix_one/  README.md

# %%
# !git add matrix_one/day3.ipynb

# %%
# !git commit -m "Read Mens Shoe Prices datasets from data.world"
# Out:
# [master 899f9b4] Read Mens Shoe Prices datasets from data.world
#  2 files changed, 2 insertions(+), 129 deletions(-)
#  rewrite .gitignore (100%)
#  create mode 100644 matrix_one/day3.ipynb

# %%
# !git config --global user.email "shymex@gmail.com"
# !git config --global user.name "Szymon J"

# %%
# !git push -u origin master
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (5/5), 12.57 KiB | 2.51 MiB/s, done.
# Total 5 (delta 0), reused 0 (delta 0)
# To https://github.com/sjaku/dw_matrix.git
#    5fe9e5b..899f9b4  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
